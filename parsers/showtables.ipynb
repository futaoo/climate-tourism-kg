# %%
import pandas as pd
import json

# %% [markdown]
# ## Aviationstack

# %% [markdown]
# ### flight data (``flight``, ``airport``, ``airline``)

# %%
f = open('./aviationstack/data/json/flights_response.json')
data = json.load(f)
df = pd.json_normalize(data,record_path="data",max_level=2)
df.columns
# Out:
# Index(['flight_date', 'flight_status', 'aircraft', 'live', 'departure.airport',
#        'departure.timezone', 'departure.iata', 'departure.icao',
#        'departure.terminal', 'departure.gate', 'departure.delay',
#        'departure.scheduled', 'departure.estimated', 'departure.actual',
#        'departure.estimated_runway', 'departure.actual_runway',
#        'arrival.airport', 'arrival.timezone', 'arrival.iata', 'arrival.icao',
#        'arrival.terminal', 'arrival.gate', 'arrival.baggage', 'arrival.delay',
#        'arrival.scheduled', 'arrival.estimated', 'arrival.actual',
#        'arrival.estimated_runway', 'arrival.actual_runway', 'airline.name',
#        'airline.iata', 'airline.icao', 'flight.number', 'flight.iata',
#        'flight.icao', 'flight.codeshared.airline_name',
#        'flight.codeshared.airline_iata', 'flight.codeshared.airline_icao',
#        'flight.codeshared.flight_number', 'flight.codeshared.flight_iata',
# ...

# %%
df
# Out:
#    flight_date flight_status  aircraft  live             departure.airport  \
# 0   2022-01-01        landed       NaN   NaN                       Barajas
# 1   2022-01-01        landed       NaN   NaN                          Dyce
# 2   2022-01-01        landed       NaN   NaN                        Hobart
# 3   2022-01-01        landed       NaN   NaN                       Fukuoka
# 4   2022-01-01        landed       NaN   NaN                Haneda Airport
# ..         ...           ...       ...   ...                           ...
# 95  2022-01-01     cancelled       NaN   NaN     Los Angeles International
# 96  2022-01-01     scheduled       NaN   NaN     Los Angeles International
# 97  2022-01-01     scheduled       NaN   NaN  John F Kennedy International
# 98  2022-01-01     scheduled       NaN   NaN  John F Kennedy International
# 99  2022-01-01        landed       NaN   NaN     Los Angeles International
#
# ...

# %% [markdown]
# ## NOAA

# %% [markdown]
# ### Daily observations (``station``, ``weather``)

# %%
df = pd.read_csv('./weather-noaa/data/daily-summaries-sample.csv')
df
# Out:
#            STATION                                     NAME  LATITUDE  \
# 0          STATION                                     NAME  LATITUDE
# 1      USW00053864  ALABASTER SHELBY CO AIRPORT ASOS, AL US  33.17835
# 2      USW00053864  ALABASTER SHELBY CO AIRPORT ASOS, AL US  33.17835
# 3      USW00053864  ALABASTER SHELBY CO AIRPORT ASOS, AL US  33.17835
# 4      USW00053864  ALABASTER SHELBY CO AIRPORT ASOS, AL US  33.17835
# ...            ...                                      ...       ...
# 50784  USC00087429                      QUINCY 3 SSW, FL US  30.54972
# 50785  USC00087429                      QUINCY 3 SSW, FL US  30.54972
# 50786  USC00087429                      QUINCY 3 SSW, FL US  30.54972
# 50787  USC00087429                      QUINCY 3 SSW, FL US  30.54972
# 50788      STATION                                     NAME  LATITUDE
#
#        LONGITUDE  ELEVATION        DATE  AWND  PRCP  SNOW  SNWD  TAVG  TMAX  \
# ...

# %% [markdown]
# ## Climatiq

# %% [markdown]
# ### Flight emission (``emission``)

# %%
cols = ["flight_id", "co2e", "co2e_unit", "source", "region", "category", "lca_activity"]
df = pd.read_csv('./climatiq-emissions/data/emissions.csv', names=cols)
df
# Out:
#       flight_id          co2e co2e_unit        source region    category  \
# 0        BA4806  15349.017755        kg  GHG Protocol     US  Air Travel
# 1        LH9376   2607.884194        kg  GHG Protocol     US  Air Travel
# 2        SK8733  17138.742202        kg  GHG Protocol     US  Air Travel
# 3        AM3656  61745.493412        kg  GHG Protocol     US  Air Travel
# 4        FJ5872  36714.918650        kg  GHG Protocol     US  Air Travel
# ...         ...           ...       ...           ...    ...         ...
# 18075     1I607   3570.926396        kg  GHG Protocol     US  Air Travel
# 18076    UA6973   3809.556322        kg  GHG Protocol     US  Air Travel
# 18077    5Y7832  16516.599894        kg  GHG Protocol     US  Air Travel
# 18078    AS4212  46822.600525        kg  GHG Protocol     US  Air Travel
# 18079   CPT8810   8641.812329        kg  GHG Protocol     US  Air Travel
#
#           lca_activity
# 0      fuel_combustion
# 1      fuel_combustion
# ...

# %% [markdown]
# ## Simplemaps

# %% [markdown]
# ### US Cities (``City``)

# %%
df = pd.read_csv('./city/data/uscities-over10k.csv')
df
# Out:
#                city state_id  state_name  latitude  longitude  population
# 0          New York       NY    New York   40.6943   -73.9249    18713220
# 1       Los Angeles       CA  California   34.1139  -118.4068    12750807
# 2           Chicago       IL    Illinois   41.8373   -87.6862     8604203
# 3             Miami       FL     Florida   25.7839   -80.2102     6445545
# 4            Dallas       TX       Texas   32.7936   -96.7662     5743938
# ...             ...      ...         ...       ...        ...         ...
# 4162        Midland       WA  Washington   47.1734  -122.4120       10005
# 4163  Bull Mountain       OR      Oregon   45.4126  -122.8322       10005
# 4164      Flat Rock       MI    Michigan   42.0991   -83.2716       10004
# 4165    Quartz Hill       CA  California   34.6527  -118.2163       10003
# 4166        Molalla       OR      Oregon   45.1502  -122.5844       10001
#
# [4167 rows x 6 columns]
